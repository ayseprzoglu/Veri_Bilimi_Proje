# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aysep\\Desktop'

# %%
covid = pd.read_csv("Cancer.csv")
covid.head(5)
# Out:
#    Unnamed: 0        Date                                              Study  \
# 0           0  2020-06-01  COVID-19 with Different Severities: A Multicen...
# 1           1  2020-06-01  Characteristics and Outcomes of COVID-19 Patie...
# 2           2  2020-05-31  Clinical Features and Short-term Outcomes of E...
# 3           3  2020-05-29  Phenotypic characteristics and prognosis of in...
# 4           4  2020-05-26  Characteristics and predictors of hospitalizat...
#
#                                           Study Link  \
# 0      https://www.ncbi.nlm.nih.gov/pubmed/32275452/
# 1  http://medrxiv.org/cgi/content/short/2020.05.2...
# 2  https://www.sciencedirect.com/science/article/...
# 3      https://www.ncbi.nlm.nih.gov/pubmed/32472191/
# 4  http://medrxiv.org/cgi/content/short/2020.05.2...
#
#                      Journal    Severe  Severe lower bound  \
# 0  Am J Respir Crit Care Med   OR 6.25                1.96
# 1                    MedRxiv       NaN                 NaN
# ...

# %%
covid["Study Type"].unique()
# Out:
# array(['Retrospective observational study',
#        'Systematic review and meta-analysis',
#        'Prospective observational study', 'Expert review',
#        'Cross-sectional study', 'Case series'], dtype=object)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               39 non-null     int64
#  1   Date                     39 non-null     object
#  2   Study                    39 non-null     object
#  3   Study Link               39 non-null     object
#  4   Journal                  38 non-null     object
#  5   Severe                   25 non-null     object
#  6   Severe lower bound       25 non-null     float64
#  7   Severe upper bound       25 non-null     float64
#  8   Severe p-value           19 non-null     object
#  9   Severe Significant       24 non-null     object
#  10  Severe Adjusted          24 non-null     object
#  11  Severe Calculated        24 non-null     object
#  12  Fatality                 22 non-null     object
#  13  Fatality lower bound     22 non-null     float64
# ...

# %%
df1 = covid[["Severe Significant","Fatality","Study Type","Discharged vs. death?"]]
df1.head(10)
# Out:
#   Severe Significant  Fatality                           Study Type  \
# 0        Significant       NaN    Retrospective observational study
# 1                NaN   OR 1.14    Retrospective observational study
# 2                NaN    HR=1.2    Retrospective observational study
# 3    Not Significant  OR: 1.55    Retrospective observational study
# 4                NaN   AOR=1.3    Retrospective observational study
# 5    Not Significant    OR=4.5    Retrospective observational study
# 6                NaN   OR=2.16  Systematic review and meta-analysis
# 7                NaN   AOR 1.0    Retrospective observational study
# 8                NaN   AOR 2.5    Retrospective observational study
# 9    Not Significant  AHR=1.29    Retrospective observational study
#
#   Discharged vs. death?
# 0                     N
# 1                     N
# 2                     N
# 3                     N
# 4                     N
# 5                     N
# 6                     N
# ...

# %%
df1.iloc[2:6]
# Out:
#   Severe Significant  Fatality                         Study Type  \
# 2                NaN    HR=1.2  Retrospective observational study
# 3    Not Significant  OR: 1.55  Retrospective observational study
# 4                NaN   AOR=1.3  Retrospective observational study
# 5    Not Significant    OR=4.5  Retrospective observational study
#
#   Discharged vs. death?
# 2                     N
# 3                     N
# 4                     N
# 5                     N

# %%
df1.loc[df1["Severe Significant"] == "Not Significant"]
# Out:
#    Severe Significant  Fatality                           Study Type  \
# 3     Not Significant  OR: 1.55    Retrospective observational study
# 5     Not Significant    OR=4.5    Retrospective observational study
# 9     Not Significant  AHR=1.29    Retrospective observational study
# 11    Not Significant       NaN  Systematic review and meta-analysis
# 12    Not Significant       NaN    Retrospective observational study
# 21    Not Significant       NaN    Retrospective observational study
# 23    Not Significant       NaN    Retrospective observational study
# 24    Not Significant       NaN  Systematic review and meta-analysis
# 28    Not Significant    OR 1.0    Retrospective observational study
# 31    Not Significant       NaN    Retrospective observational study
# 32    Not Significant       NaN                Cross-sectional study
# 34    Not Significant       NaN  Systematic review and meta-analysis
# 38    Not Significant       NaN                          Case series
#
# ...
