# %%
import numpy as np
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
os.chdir('Mutluluk')
os.getcwd()
# Out:
# 'C:\\Users\\aysep\\Desktop\\Mutluluk'

# %%
data=pd.read_csv("2015.csv")

# %%
data.info()

data.shape  #data boyutu
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data.isnull().sum()  # kayıp veri bilgisi
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
len(data["Country"].unique())  #Ka tane ülke var
# Out:
# 158

# %%
sns.barplot(y = data["Country"][:10], x = data["Happiness Score"][:10])  # En mutlu 10 ülkenin grafiği
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Country'>

# %%
sns.barplot(y = data["Country"][-10:], x = data["Happiness Score"][-10:]) #En mutsuz 10 ülkenin grafiği
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Country'>

# %%
data_turk = data[data["Country"]=="Turkey"]
data_turk
# Out:
#    Country                           Region  Happiness Rank  Happiness Score  \
# 75  Turkey  Middle East and Northern Africa              76            5.332
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 75         0.03864                   1.06098  0.94632
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 75                   0.73172  0.22815                        0.15746
#
#     Generosity  Dystopia Residual
# 75     0.12253            2.08528

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aysep\\Desktop\\Mutluluk'

# %%
f, axs = plt.subplots(3,2, figsize = (14,14), constrained_layout = True)

sort_eco = data.sort_values(by = ['Economy (GDP per Capita)'], ascending = False)
sort_eco = sort_eco.head(10)
sort_fa = data.sort_values(by = ['Family'], ascending = False)
sort_fa = sort_fa.head(10)
sort_he = data.sort_values(by = ['Health (Life Expectancy)'], ascending = False)
sort_he = sort_he.head(10)
sort_free = data.sort_values(by = ['Freedom'], ascending = False)
sort_free = sort_free.head(10)
sort_gc = data.sort_values(by = ['Trust (Government Corruption)'], ascending = False)
sort_gc = sort_gc.head(10)
sort_genero = data.sort_values(by = ['Generosity'], ascending = False)
sort_genero = sort_genero.head(10)

ax=sns.barplot(x="Country", y="Economy (GDP per Capita)", data=sort_eco, ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Family", data=sort_fa, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Health (Life Expectancy)", data=sort_he, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Freedom", data=sort_free, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Trust (Government Corruption)", data = sort_gc, ax = axs[2, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Generosity", data=sort_genero, ax = axs[2, 1])
ax.tick_params(axis = 'x', rotation = 45)

# %% [markdown]
# Tüm Yıllar

# %%
df_16=pd.read_csv('2016.csv')
df_17=pd.read_csv('2017.csv')
df_18=pd.read_csv('2018.csv')
df_19=pd.read_csv('2019.csv')

# %%
df_16.columns=df_16.columns.str.replace(' ','_')

# %%
df_16.tail(10)
# Out:
#          Country                           Region  Happiness_Rank  \
# 147   Madagascar               Sub-Saharan Africa             148
# 148     Tanzania               Sub-Saharan Africa             149
# 149      Liberia               Sub-Saharan Africa             150
# 150       Guinea               Sub-Saharan Africa             151
# 151       Rwanda               Sub-Saharan Africa             152
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness_Score  Lower_Confidence_Interval  Upper_Confidence_Interval  \
# 147            3.695                      3.621                      3.769
# 148            3.666                      3.561                      3.771
# ...

# %%
df_17.columns=df_17.columns.str.replace(' ','_')

# %%
df_17.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df_18.columns=df_18.columns.str.replace(' ','_')

# %%
df_18.columns
# Out:
# Index(['Overall_rank', 'Country_or_region', 'Score', 'GDP_per_capita',
#        'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
df_19.columns=df_19.columns.str.replace(' ','_')

# %%
df_19.columns
# Out:
# Index(['Overall_rank', 'Country_or_region', 'Score', 'GDP_per_capita',
#        'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
df_18.head(8)
# Out:
#    Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# ...

# %%
sort_data = data.head(10)
sort_df_16 = df_16.head(10)
sort_df_17 = df_17.head(10)
sad_df_17 = df_19.tail(10)
f, axs = plt.subplots(2,2, figsize = (14,14), constrained_layout = True)
ax=sns.barplot(x="Country", y="Happiness Score", data=sort_data , ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data=sort_df_16, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness.Score", data=sort_df_17, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness.Score", data=sad_df_17, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)

axs[0, 0].title.set_text('2015 YILI EN MUTLU 10 ULKE')
axs[0, 1].title.set_text('2016 YILI EN MUTLU 10 ULKE')
axs[1, 0].title.set_text('2017 YILI EN MUTLU 10 ULKE')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14712\1408839935.py in <module>
#      10 ax=sns.barplot(x="Country",y="Happiness.Score", data=sort_df_17, ax = axs[1, 0])
#      11 ax.tick_params(axis = 'x', rotation = 45)
# ---> 12 ax=sns.barplot(x="Country",y="Happiness.Score", data=sad_df_17, ax = axs[1, 1])
#      13 ax.tick_params(axis = 'x', rotation = 45)
#      14
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
